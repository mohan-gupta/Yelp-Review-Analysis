# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598000 entries, 0 to 597999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    598000 non-null  object
#  1   label   598000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 9.1+ MB

# %%
p_df = pd.read_csv("../dataset/processed_data.csv")

# %%
p_df.shape
# Out:
# (598000, 2)

# %%
p_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598000 entries, 0 to 597999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   text       597948 non-null  object
#  1   sentiment  598000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 9.1+ MB

# %%
p_df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 597948 entries, 0 to 597999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   text       597948 non-null  object
#  1   sentiment  597948 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 13.7+ MB

# %%
p_df.isnull().sum()
# Out:
# text         52
# sentiment     0
# dtype: int64

# %%
df[p_df['text'].isna()]
# Out:
#                                                      text  label
# 8826                                                    A      0
# 9483           http://www.youtube.com/watch?v=OfMy1uMjkdw      1
# 13939                                                   1      0
# 27292                                                 :-(      0
# 32504                              ----------------------      1
# 34763                                                 ...      1
# 38147                 ...................................      0
# 44695                    http://parismusings.blogspot.com      1
# 47114   http://www.courthousenews.com/2013/07/03/59061...      0
# 54760                                               (*-*)      1
# 57810                                        Not the same      0
# 64321                                               .....      0
# 72200                                                 ***      1
# ...
